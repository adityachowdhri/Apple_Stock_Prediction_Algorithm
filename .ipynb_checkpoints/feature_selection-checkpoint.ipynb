# %%
##Import Statements
import yfinance as yf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
from pandas.plotting import register_matplotlib_converters
from statsmodels.tsa.seasonal import STL

# %%
#Function to add ticker
def tickAdder(ticker):
    tick = yf.Ticker(ticker)
    tick = tick.history(start="1999-08-15", end="2024-06-07")
    return tick

# %%
#Function to plot Corr Matrix
def corrMatrix(dataframe):
    correlation_matrix = dataframe.corr()
    plt.figure(figsize=(10, 8))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
    plt.title('Correlation Matrix')
    plt.show()

# %%
def timePlot(y, colName, ticker_symbol, start, end):
    y.plot()
    plt.xlim(start, end)
    plt.xlabel('Date')
    plt.ylabel( colName + ' Price')
    plt.title('Price of {}'.format(ticker_symbol))
    plt.grid(True)
    plt.show()

# %%
##Import Apple Data
data = yf.Ticker("aapl")
data = data.history(start="1999-08-15", end="2024-06-07")

# %%
#Naive Seasonal Decomposition 
#Identify Trend, seasonal, and residual components of close
result = seasonal_decompose(data['Close'], model='multiplicative', period=1)

# %%
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['Close'], label="Apple Stock Price")
plt.title("Apple Stock Price")
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.show()

# %%
# Simple Seasonal Decomposition Model
plt.figure(figsize=(12, 8))
plt.subplot(4, 1, 1)
plt.plot(result.trend, label='Trend')
plt.title('Trend Component')
# (Similar blocks for Seasonal and Residual components)

plt.subplot(4, 1, 2)
plt.plot(result.resid, label='Residual')
plt.title('Residual Component')
# (Similar blocks for Seasonal and Residual components)

plt.subplot(4, 1, 3)
plt.plot(result.seasonal, label='Seasonal')
plt.title('Seasonal Component')
# (Similar blocks for Seasonal and Residual components)

plt.subplot(4, 1, 4)
plt.plot(data['Close'], label= "Apple Stock Price")
plt.title("Apple Stock Prices")
plt.tight_layout()
plt.show()

# %%
#Complex Seasonal Decomposition Model 
from statsmodels.tsa.seasonal import STL
stl = STL(data["Close"], period = 365)
res = stl.fit()
fig = res.plot()
res.resid.shape
# Out:
# (6003,)

# %%
#Adding Trend and Seasonality to our model 
data["Trend"] = res.trend
data["Seasonality"] = res.seasonal
# Out:
# /var/folders/xk/v8z12vfx3c5gp782bqrr8gf80000gq/T/ipykernel_39215/1318669711.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Trend"] = res.trend
# /var/folders/xk/v8z12vfx3c5gp782bqrr8gf80000gq/T/ipykernel_39215/1318669711.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Seasonality"] = res.seasonal

# %%
##Feature Implementation 

#Rolling averages
data['SMA_50'] = data['Close'].rolling(window=50).mean()
data['SMA_100'] = data['Close'].rolling(window=100).mean()
data['SMA_200'] = data['Close'].rolling(window=200).mean()

#Volatility indicator
data['std_20'] = data['Close'].rolling(window=20).std()

# Calculate Technical Indicators (RSI)
delta = data['Close'].diff(1)
gain = (delta.where(delta > 0, 0)).rolling(window=14).mean()
loss = (-delta.where(delta < 0, 0)).rolling(window=14).mean()
rs = gain / loss
data['RSI'] = 100 - (100 / (1 + rs))

# Calculate lagged values
data['Close_lag1'] = data['Close'].shift(1)
data['Close_lag5'] = data['Close'].shift(5)
# Out:
# /var/folders/xk/v8z12vfx3c5gp782bqrr8gf80000gq/T/ipykernel_39215/3241442759.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_50'] = data['Close'].rolling(window=50).mean()
# /var/folders/xk/v8z12vfx3c5gp782bqrr8gf80000gq/T/ipykernel_39215/3241442759.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_100'] = data['Close'].rolling(window=100).mean()
# /var/folders/xk/v8z12vfx3c5gp782bqrr8gf80000gq/T/ipykernel_39215/3241442759.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['SMA_200'] = data['Close'].rolling(window=200).mean()
# /var/folders/xk/v8z12vfx3c5gp782bqrr8gf80000gq/T/ipykernel_39215/3241442759.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['std_20'] = data['Close'].rolling(window=20).std()
# /var/folders/xk/v8z12vfx3c5gp782bqrr8gf80000gq/T/ipykernel_39215/3241442759.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RSI'] = 100 - (100 / (1 + rs))
# /var/folders/xk/v8z12vfx3c5gp782bqrr8gf80000gq/T/ipykernel_39215/3241442759.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Close_lag1'] = data['Close'].shift(1)
# /var/folders/xk/v8z12vfx3c5gp782bqrr8gf80000gq/T/ipykernel_39215/3241442759.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Close_lag5'] = data['Close'].shift(5)

# %%
#Ensure that there exist no null values
data = data[202:]
data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2003-08-22 00:00:00-04:00    0.329720    0.332592    0.312032    0.315661
# 2003-08-25 00:00:00-04:00    0.314148    0.316114    0.309765    0.315358
# 2003-08-26 00:00:00-04:00    0.313696    0.318533    0.307648    0.318231
# 2003-08-27 00:00:00-04:00    0.316114    0.324731    0.312335    0.324731
# 2003-08-28 00:00:00-04:00    0.322464    0.335919    0.322464    0.335465
# ...                               ...         ...         ...         ...
# 2024-04-08 00:00:00-04:00  169.029999  169.199997  168.240005  168.449997
# 2024-04-09 00:00:00-04:00  168.699997  170.080002  168.350006  169.669998
# 2024-04-10 00:00:00-04:00  168.800003  169.089996  167.110001  167.779999
# 2024-04-11 00:00:00-04:00  168.339996  175.460007  168.160004  175.039993
# 2024-04-12 00:00:00-04:00  174.259995  178.360001  174.210007  176.550003
#
#                               Volume  Dividends  Stock Splits      SMA_50  \
# Date
# 2003-08-22 00:00:00-04:00  250264000        0.0           0.0    0.301105
# 2003-08-25 00:00:00-04:00  137782400        0.0           0.0    0.302145
# 2003-08-26 00:00:00-04:00  164959200        0.0           0.0    0.302986
# 2003-08-27 00:00:00-04:00  225702400        0.0           0.0    0.303981
# 2003-08-28 00:00:00-04:00  319625600        0.0           0.0    0.304909
# ...                              ...        ...           ...         ...
# 2024-04-08 00:00:00-04:00   37425500        0.0           0.0  178.379980
# 2024-04-09 00:00:00-04:00   42451200        0.0           0.0  177.929885
# 2024-04-10 00:00:00-04:00   49709300        0.0           0.0  177.455771
# 2024-04-11 00:00:00-04:00   91070300        0.0           0.0  177.200564
# 2024-04-12 00:00:00-04:00  101593300        0.0           0.0  177.048264
#
#                               SMA_100     SMA_200    std_20        RSI  \
# Date
# 2003-08-22 00:00:00-04:00    0.272428    0.248195  0.009230  47.245324
# 2003-08-25 00:00:00-04:00    0.273375    0.248470  0.009140  54.632950
# 2003-08-26 00:00:00-04:00    0.274371    0.248852  0.009347  65.367800
# 2003-08-27 00:00:00-04:00    0.275440    0.249278  0.010000  66.315396
# 2003-08-28 00:00:00-04:00    0.276604    0.249810  0.011416  74.661614
# ...                               ...         ...       ...        ...
# 2024-04-08 00:00:00-04:00  184.411684  182.710795  2.557937  40.358562
# 2024-04-09 00:00:00-04:00  184.262739  182.627823  2.588898  37.762485
# 2024-04-10 00:00:00-04:00  184.068528  182.536994  2.695639  28.638662
# 2024-04-11 00:00:00-04:00  183.941224  182.489488  2.817712  57.210222
# 2024-04-12 00:00:00-04:00  183.812041  182.435637  3.018676  58.195794
#
#                            Close_lag1  Close_lag5       Trend  Seasonality
# Date
# 2003-08-22 00:00:00-04:00    0.327755    0.297972    0.314730     0.101538
# 2003-08-25 00:00:00-04:00    0.315661    0.307497    0.315285     0.109445
# 2003-08-26 00:00:00-04:00    0.315358    0.307195    0.315845     0.127726
# 2003-08-27 00:00:00-04:00    0.318231    0.317626    0.316411     0.127642
# 2003-08-28 00:00:00-04:00    0.324731    0.327755    0.316983     0.121240
# ...                               ...         ...         ...          ...
# 2024-04-08 00:00:00-04:00  169.580002  170.029999  184.192717   -16.928884
# 2024-04-09 00:00:00-04:00  168.449997  168.839996  184.275759   -14.991152
# 2024-04-10 00:00:00-04:00  169.669998  169.649994  184.358835   -14.759908
# 2024-04-11 00:00:00-04:00  167.779999  168.820007  184.441943   -11.575955
# 2024-04-12 00:00:00-04:00  175.039993  169.580002  184.525085   -12.713972
#
# [5195 rows x 16 columns]

# %%
close_prices = data['Close']

# Calculate autocorrelation using pandas autocorr() function
autocorr_values = close_prices.autocorr()

# Plot autocorrelation function (ACF)
pd.plotting.autocorrelation_plot(close_prices)
plt.title('Autocorrelation Plot of Apple Stock Prices')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.show()

# %%
#Common Data Cleaning 

timePlot(data["Close"], "Open", "AAPL", "2020-04-10", "2024-04-10")

# %%
corrMatrix(data)

# %%
#Iteration 1

# %%
#Add msft ticker
msft = tickAdder("msft")
nvda = tickAdder("nvda")

# %%
data["Close Nvidia"] = nvda["Close"]

# %%
corrMatrix(data)
